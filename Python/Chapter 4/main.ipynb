# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/ADMIN/Downloads/sample_data.csv')
df.head()
# Out:
#          Date     Product     Category  Units_Sold  Unit_Price  Revenue  \
# 0  2024-01-01      Laptop  Electronics          15        1200    18000
# 1  2024-01-02  Smartphone  Electronics          40         800    32000
# 2  2024-01-03      Tablet  Electronics          25         400    10000
# 3  2024-01-04     Monitor  Accessories          30         300     9000
# 4  2024-01-05  Headphones  Accessories          50         150     7500
#
#     Region
# 0    North
# 1     East
# 2     West
# 3    South
# 4  Central

# %%
high_revenue = df[df['Revenue'] > 400]
high_revenue
# Out:
#          Date     Product     Category  Units_Sold  Unit_Price  Revenue  \
# 0  2024-01-01      Laptop  Electronics          15        1200    18000
# 1  2024-01-02  Smartphone  Electronics          40         800    32000
# 2  2024-01-03      Tablet  Electronics          25         400    10000
# 3  2024-01-04     Monitor  Accessories          30         300     9000
# 4  2024-01-05  Headphones  Accessories          50         150     7500
# 5  2024-01-06    Keyboard  Accessories          45          50     2250
# 6  2024-01-07       Mouse  Accessories          60          25     1500
# 7  2024-01-08     Charger  Electronics          20          30      600
#
#     Region
# 0    North
# 1     East
# 2     West
# 3    South
# 4  Central
# 5    North
# 6     East
# 7     West

# %%
data_sorted = df.sort_values('Revenue', ascending=False)
data_sorted.head()
# Out:
#          Date     Product     Category  Units_Sold  Unit_Price  Revenue  \
# 1  2024-01-02  Smartphone  Electronics          40         800    32000
# 0  2024-01-01      Laptop  Electronics          15        1200    18000
# 2  2024-01-03      Tablet  Electronics          25         400    10000
# 3  2024-01-04     Monitor  Accessories          30         300     9000
# 4  2024-01-05  Headphones  Accessories          50         150     7500
#
#     Region
# 1     East
# 0    North
# 2     West
# 3    South
# 4  Central

# %%
plt.rcParams['figure.figsize'] = [10, 6]
df.plot(x='Product', y='Revenue', kind='line')
plt.title("Product by Revenue")
plt.xlabel("Products")
plt.ylabel("Revenue")
plt.show()

# %%
df.plot(x='Product', y='Unit_Price', kind='bar')
plt.title("Product by Revenue")
plt.xlabel("Products")
plt.ylabel("Revenue")
plt.show()
